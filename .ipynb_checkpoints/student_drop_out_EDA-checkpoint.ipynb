# %%
# Importing  libraries and visualisation tools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data.csv', delimiter=';')

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df['Nacionality'].unique()
# Out:
# array([  1,  62,   6,  41,  26, 103,  13,  25,  21, 101,  11,  22,  32,
#        100,  24, 109,   2, 108, 105,  14,  17], dtype=int64)

# %%
sns.countplot(x='Target', data=df)
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %%
# plotting cat features 
categorical_features = ['Marital status', 'Application mode', 'Course']
for col in categorical_features:
    sns.countplot(x=col, data=df)
    plt.show()

# %%
df["Marital status"].unique()
# Out:
# array([1, 2, 4, 3, 5, 6], dtype=int64)

# %%
# exploring numerical features 
numerical_features = ['Previous qualification (grade)', 'Unemployment rate', 'GDP', ...]
for col in numerical_features:
    sns.histplot(df[col], kde=True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Ellipsis
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
# ...

# %%
# previous qualification vs target
sns.boxplot(x='Target', y='Previous qualification (grade)', data=df)
# Out:
# <Axes: xlabel='Target', ylabel='Previous qualification (grade)'>

# %%
sns.barplot(x='Target', y='Marital status', data=df)
# Out:
# <Axes: xlabel='Target', ylabel='Marital status'>

# %%
sns.barplot(x='Target', y='Unemployment rate', data=df)
# Out:
# <Axes: xlabel='Target', ylabel='Unemployment rate'>

# %%
sns.barplot(x='Target', y='Gender', data=df)
# Out:
# <Axes: xlabel='Target', ylabel='Gender'>

# %%
'''
plt.figure(figsize=(10,10))
plt.title('Academic Status')
plt.pie['Target'].value_counts(),labels = ['Graduate','Dropout','Emrolled']}
plt.legend(loc = 'lower right')
#sns.barplot(x='Target', y='Gender', data=df)
'''
target_counts = df['Target'].value_counts()

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(target_counts, labels=target_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99'])
plt.title("Distribution of Target Variable (Graduate vs. Dropout)")
plt.show()

# %%
# Calculate the value counts for each class in the target variable
target_counts = df['Target'].value_counts()
labels = target_counts.index  # Labels for the pie chart (e.g., 'Graduate', 'Dropout')
sizes = target_counts.values   # Values for each class

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999'])
plt.title('Distribution of Target Variable (Graduate vs Dropout)')
plt.show()

# %%
# Plot a bar chart for gender distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df, palette='pastel')

plt.xticks([1, 0], ['Male', 'Female'])

plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27024\3363306092.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='pastel')

# %%
# Plot a bar chart for gender distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df, palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27024\1269209580.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='pastel')

# %%
# Assuming 'Gender' and 'Target' columns exist in your DataFrame
plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', hue='Target', data=df, palette='Set2')
plt.xticks([1, 0], ['Male', 'Female'])
plt.title('Gender Distribution by Target')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Target')
plt.show()

# %%
# Plotting gender distribution with custom labels for 0 and 1
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df, palette='pastel')
plt.xticks([1, 0], ['Male', 'Female'])  # Custom labels for gender
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27024\646591346.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='pastel')

# %%
df['Gender'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    2868
# 1    1556
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Unemployment rate', hue='Target', data=df, palette='Set1')
plt.title('Unemployment Level by Target')
plt.xlabel('Unemployment Rate Level')
plt.ylabel('Count')
plt.legend(title='Target')
plt.xticks(rotation=45)  # Rotate labels if needed
plt.show()

# %%
df['Unemployment rate'].unique().sum()
# Out:
# 118.5

# %%
sns.pairplot(df[['GDP', 'Unemployment rate', 'Inflation rate', 'Curricular units 2nd sem (grade)','Admission grade']])
plt.show()

# %%
cross_tab = pd.crosstab(df['Gender'], df['Debtor'])
sns.heatmap(cross_tab, annot=True, cmap='YlGnBu', fmt="d")
plt.title('Heatmap of Gender vs Debtor')
plt.xlabel('Gender')
plt.ylabel('Debtor')
plt.show()

# %%
df['Curricular units 2nd sem (grade)']
# Out:
# 0        0.000000
# 1       13.666667
# 2        0.000000
# 3       12.400000
# 4       13.000000
#           ...
# 4419    12.666667
# 4420    11.000000
# 4421    13.500000
# 4422    12.000000
# 4423    13.000000
# Name: Curricular units 2nd sem (grade), Length: 4424, dtype: float64

# %%
df['Curricular units 1st sem (grade)']
# Out:
# 0        0.000000
# 1       14.000000
# 2        0.000000
# 3       13.428571
# 4       12.333333
#           ...
# 4419    13.600000
# 4420    12.000000
# 4421    14.912500
# 4422    13.800000
# 4423    11.666667
# Name: Curricular units 1st sem (grade), Length: 4424, dtype: float64

# %%
# Histogram with KDE for 1st semester grades
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Curricular units 1st sem (grade)', hue='Target', kde=True, element="step")
plt.title('1st Sem Grade Distribution by Target')
plt.show()

# %%
# Histogram with KDE for 2nd semester grades
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Curricular units 2nd sem (grade)', hue='Target', kde=True, element="step")
plt.title('2nd Sem Grade Distribution by Target')
plt.show()

# %%
g = sns.FacetGrid(df, col="Target", height=5, aspect=1)
g.map(sns.histplot, "Curricular units 1st sem (grade)", kde=True)
g.map(sns.histplot, "Curricular units 2nd sem (grade)", kde=True, color="orange")
g.add_legend()
plt.show()

# %%
df['Target'].unique()
# Out:
# array([0, 2, 1])

# %%
cross_tab = pd.crosstab(df['Tuition fees up to date'], df['Gender'])
sns.heatmap(cross_tab, annot=True, cmap='YlGnBu', fmt="d")
plt.title('Tuition fees up to date vs Gender')
plt.xlabel('Tuition fees up to date')
plt.ylabel('Gender')
plt.show()

# %%
sns.countplot(x='Gender', hue='Debtor', data=df, palette='Set2')
plt.title('Gender and Debtor')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Debtor')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Example: Encode the 'Target' column
label_encoder = LabelEncoder()
df['Target'] = label_encoder.fit_transform(df['Target'])

# Now, you can check the DataFrame to see that the 'Target' column is numeric
print(df['Target'].head())
# Out:
# 0    0
# 1    2
# 2    0
# 3    2
# 4    2
# Name: Target, dtype: int32

# %%
# Example: One-Hot Encoding for categorical columns
df_encoded = pd.get_dummies(df, columns=['Marital status', 'Application mode', 'Course', 'Previous qualification'], drop_first=True)

# Now check the encoded DataFrame
print(df_encoded.head())
# Out:
#    Application order  Daytime/evening attendance\t  \
# 0                  5                             1
# 1                  1                             1
# 2                  5                             1
# 3                  2                             1
# 4                  1                             0
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
#    Father's qualification  Mother's occupation  Father's occupation  \
# 0                      12                    5                    9
# 1                       3                    3                    3
# ...

# %%
correlation_matrix = df.corr(method='pearson')

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Pearson Correlation Matrix')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# using pearson correlation to compare between features 
correlation_value = df['GDP'].corr(df['Unemployment rate'], method='pearson')
print(f"Pearson correlation between GDP and Unemployment rate: {correlation_value}")
# Out:
# Pearson correlation between GDP and Unemployment rate: -0.3351781190260065

# %%
# Assuming 'df' is your DataFrame
# Calculate correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
correlation_with_target = df.corr(method='pearson')['Target']

# Display the correlation values with the target feature
print(correlation_with_target)

# %%
# using spearman correlation ( non linear)
# Calculate Spearman correlation between all features and the target
correlation_with_target_spearman = df.corr(method='spearman')['Target']

# Display the correlation values with the target feature
print(correlation_with_target_spearman)

# %%
# Scatter plot of two variables, say 'Feature1' and 'Target'
plt.scatter(df['Curricular units 2nd sem (approved)'], df['Target'])
plt.title('Scatter Plot: Feature1 vs Target')
plt.xlabel('Feature1')
plt.ylabel('Target')
plt.show()

# %%
df_2= df.drop(columns=["Target"])

# %%
df_2.head(2)

# %%
# corelation analysis 
correlation_matrix = df_2.corr()
plt.figure(figsize=(12, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df_2
